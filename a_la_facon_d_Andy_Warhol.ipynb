# %% [markdown]
# # A la façon d'Andy Warhol
#
# Le programme suivant va vous permettre de modifier les couleurs de l'image choisie.
#
# Pour commencer on va installer le package `pillow` qui n'est pas par défaut dans Python.

# %%
import sys
# !{sys.executable} -m pip install pillow

# %% [markdown]
# On peut maintenant faire tourner notre programme. Pour cela, il vous suffira d'écrire le nom de l'image que vous voulez modifier à la ligne 2 et de modifier les couleurs à la ligne 11.
#
# *Attention !* Toutes vos images modifiées auront le même nom si vous ne modifiez pas aussi la ligne 14)

# %%
from PIL import Image
img = Image.open('images/une_image.jpg')

largeur, hauteur = img.size
print('Nombre de pixels en largeur :', largeur)
print('Nombre de pixels en hauteur :', hauteur)

for x in range(largeur):
    for y in range(hauteur):
        R, V, B = img.getpixel((x, y))
        img.putpixel((x, y),(R, V, B))

img.show()
img.save("nouvelle_image.jpg")
